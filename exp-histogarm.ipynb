# %%
import matplotlib.pyplot as plt
wages =[2,5,70,40,30,45,50,45,45,48,41,60,7,18,57,18,90,77,32,21,20,40]
range=(0,100)
bins=10
plt.hist(wages,bins,range,color='grey',histtype='bar',rwidth=0.8)
plt.xlabel('age')
plt.ylabel('no of people')
plt.title('my histogram')
plt.show()
